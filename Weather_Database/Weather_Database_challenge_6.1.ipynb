# %% [markdown]
# # challenge 6.1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities. To store cities names
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 790

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. Ask Mark
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities. Ask Mark
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description
                          #"Date": city_date
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | jijiga
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | rudbar
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | semnan
# Processing Record 10 of Set 1 | mandan
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | agadir
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | saint-joseph
# Processing Record 16 of Set 1 | chake chake
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | awjilah
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | tabou
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | ulaangom
# Processing Record 24 of Set 1 | ambon
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | narsaq
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | port hardy
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | yayva
# Processing Record 32 of Set 1 | santa maria do suacui
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | hami
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | pangnirtung
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | rawson
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | senj
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | russell
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | leh
# Processing Record 5 of Set 2 | salamiyah
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | safaga
# Processing Record 8 of Set 2 | kangaatsiaq
# Processing Record 9 of Set 2 | san juan
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | imbituba
# Processing Record 12 of Set 2 | obihiro
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | luanda
# Processing Record 18 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | luocheng
# Processing Record 21 of Set 2 | aykhal
# Processing Record 22 of Set 2 | cambrai
# Processing Record 23 of Set 2 | charters towers
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | nome
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | piracicaba
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | hambantota
# Processing Record 31 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 32 of Set 2 | revelstoke
# Processing Record 33 of Set 2 | agirish
# Processing Record 34 of Set 2 | khandyga
# Processing Record 35 of Set 2 | schwedt
# Processing Record 36 of Set 2 | calabozo
# Processing Record 37 of Set 2 | aberlour
# City not found. Skipping...
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | tumbi
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | miyako
# Processing Record 43 of Set 2 | aksu
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | walvis bay
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | faanui
# Processing Record 48 of Set 2 | maarianhamina
# Processing Record 49 of Set 2 | takab
# Processing Record 50 of Set 2 | sakakah
# Processing Record 1 of Set 3 | lorengau
# Processing Record 2 of Set 3 | vao
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | saint anthony
# Processing Record 5 of Set 3 | ocampo
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | mango
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | sinegorye
# Processing Record 13 of Set 3 | sungaipenuh
# Processing Record 14 of Set 3 | dubti
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | debrecen
# Processing Record 17 of Set 3 | vanimo
# Processing Record 18 of Set 3 | bah
# Processing Record 19 of Set 3 | maniitsoq
# Processing Record 20 of Set 3 | angoche
# Processing Record 21 of Set 3 | gizo
# Processing Record 22 of Set 3 | klaksvik
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | xai-xai
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | mabai
# Processing Record 28 of Set 3 | kahului
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | aklavik
# Processing Record 32 of Set 3 | mubi
# Processing Record 33 of Set 3 | tiznit
# Processing Record 34 of Set 3 | sawtell
# Processing Record 35 of Set 3 | krasnoselkup
# Processing Record 36 of Set 3 | ano mera
# Processing Record 37 of Set 3 | somogyvar
# Processing Record 38 of Set 3 | grenaa
# Processing Record 39 of Set 3 | adrar
# Processing Record 40 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 3 | shingu
# Processing Record 42 of Set 3 | samborondon
# Processing Record 43 of Set 3 | tiarei
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | nouadhibou
# Processing Record 46 of Set 3 | hofn
# Processing Record 47 of Set 3 | fort nelson
# Processing Record 48 of Set 3 | taunggyi
# Processing Record 49 of Set 3 | madang
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | wad madani
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | zemio
# Processing Record 5 of Set 4 | cherepanovo
# Processing Record 6 of Set 4 | veletma
# City not found. Skipping...
# Processing Record 7 of Set 4 | taltal
# Processing Record 8 of Set 4 | rio gallegos
# Processing Record 9 of Set 4 | jalu
# Processing Record 10 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | saint-augustin
# Processing Record 13 of Set 4 | cravo norte
# Processing Record 14 of Set 4 | mweka
# Processing Record 15 of Set 4 | richards bay
# Processing Record 16 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 4 | coihaique
# Processing Record 18 of Set 4 | barra do bugres
# Processing Record 19 of Set 4 | sulangan
# Processing Record 20 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 4 | bossangoa
# Processing Record 22 of Set 4 | mongar
# Processing Record 23 of Set 4 | gotsu
# Processing Record 24 of Set 4 | cabra
# Processing Record 25 of Set 4 | sabang
# Processing Record 26 of Set 4 | fairbanks
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | ardabil
# Processing Record 29 of Set 4 | beyneu
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | shetpe
# Processing Record 32 of Set 4 | lingao
# Processing Record 33 of Set 4 | ekhabi
# Processing Record 34 of Set 4 | isakly
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | manavalakurichi
# Processing Record 37 of Set 4 | kenai
# Processing Record 38 of Set 4 | yar-sale
# Processing Record 39 of Set 4 | san pedro
# Processing Record 40 of Set 4 | gallup
# Processing Record 41 of Set 4 | bafq
# Processing Record 42 of Set 4 | porto novo
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | cherskiy
# Processing Record 45 of Set 4 | rio do sul
# Processing Record 46 of Set 4 | bardiyah
# Processing Record 47 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | beloha
# Processing Record 50 of Set 4 | souillac
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | talara
# Processing Record 3 of Set 5 | lazurne
# Processing Record 4 of Set 5 | nong phai
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 7 of Set 5 | cayenne
# Processing Record 8 of Set 5 | grand gaube
# Processing Record 9 of Set 5 | weatherford
# Processing Record 10 of Set 5 | natal
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | tymovskoye
# Processing Record 13 of Set 5 | burnie
# Processing Record 14 of Set 5 | mayo
# Processing Record 15 of Set 5 | buala
# Processing Record 16 of Set 5 | vega de alatorre
# Processing Record 17 of Set 5 | haines junction
# Processing Record 18 of Set 5 | faya
# Processing Record 19 of Set 5 | itainopolis
# Processing Record 20 of Set 5 | boyolangu
# Processing Record 21 of Set 5 | niamey
# Processing Record 22 of Set 5 | camana
# Processing Record 23 of Set 5 | cotonou
# Processing Record 24 of Set 5 | katobu
# Processing Record 25 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 5 | bethel
# Processing Record 27 of Set 5 | kimbe
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | karak
# Processing Record 31 of Set 5 | eureka
# Processing Record 32 of Set 5 | tezu
# Processing Record 33 of Set 5 | kirakira
# Processing Record 34 of Set 5 | fulitun
# City not found. Skipping...
# Processing Record 35 of Set 5 | port elizabeth
# Processing Record 36 of Set 5 | harper
# Processing Record 37 of Set 5 | poya
# Processing Record 38 of Set 5 | tuy hoa
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | tobermory
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | tingi
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | broome
# Processing Record 45 of Set 5 | kegalla
# City not found. Skipping...
# Processing Record 46 of Set 5 | nevel
# Processing Record 47 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | usinsk
# Processing Record 50 of Set 5 | longyearbyen
# Processing Record 1 of Set 6 | matagami
# Processing Record 2 of Set 6 | buraydah
# Processing Record 3 of Set 6 | thabazimbi
# Processing Record 4 of Set 6 | pascagoula
# Processing Record 5 of Set 6 | songjianghe
# Processing Record 6 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 6 | vysokoye
# Processing Record 8 of Set 6 | karratha
# Processing Record 9 of Set 6 | copiapo
# Processing Record 10 of Set 6 | snezhnogorsk
# Processing Record 11 of Set 6 | luderitz
# Processing Record 12 of Set 6 | pidhaytsi
# Processing Record 13 of Set 6 | flin flon
# Processing Record 14 of Set 6 | kishtwar
# Processing Record 15 of Set 6 | ronne
# Processing Record 16 of Set 6 | olafsvik
# Processing Record 17 of Set 6 | naze
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 6 | belle glade
# Processing Record 21 of Set 6 | port-cartier
# Processing Record 22 of Set 6 | labuhan
# Processing Record 23 of Set 6 | hobyo
# Processing Record 24 of Set 6 | husavik
# Processing Record 25 of Set 6 | denpasar
# Processing Record 26 of Set 6 | plettenberg bay
# Processing Record 27 of Set 6 | roald
# Processing Record 28 of Set 6 | mont-dore
# Processing Record 29 of Set 6 | provideniya
# Processing Record 30 of Set 6 | wanning
# Processing Record 31 of Set 6 | bilibino
# Processing Record 32 of Set 6 | caiaponia
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | san carlos
# Processing Record 35 of Set 6 | varangaon
# Processing Record 36 of Set 6 | salinopolis
# Processing Record 37 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 6 | sobolevo
# Processing Record 39 of Set 6 | west wendover
# Processing Record 40 of Set 6 | altoona
# Processing Record 41 of Set 6 | yining
# Processing Record 42 of Set 6 | hasaki
# Processing Record 43 of Set 6 | san jeronimo
# Processing Record 44 of Set 6 | gornopravdinsk
# Processing Record 45 of Set 6 | chinhoyi
# Processing Record 46 of Set 6 | borazjan
# Processing Record 47 of Set 6 | gat
# Processing Record 48 of Set 6 | shenxian
# Processing Record 49 of Set 6 | jardim
# Processing Record 50 of Set 6 | trelew
# Processing Record 1 of Set 7 | kaeo
# Processing Record 2 of Set 7 | asyut
# Processing Record 3 of Set 7 | norman wells
# Processing Record 4 of Set 7 | esperance
# Processing Record 5 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 7 | bintulu
# Processing Record 7 of Set 7 | bhadohi
# Processing Record 8 of Set 7 | voi
# Processing Record 9 of Set 7 | emba
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | zyryanka
# Processing Record 12 of Set 7 | nanortalik
# Processing Record 13 of Set 7 | mehamn
# Processing Record 14 of Set 7 | chicama
# Processing Record 15 of Set 7 | riachao das neves
# Processing Record 16 of Set 7 | oranjemund
# Processing Record 17 of Set 7 | gravdal
# Processing Record 18 of Set 7 | doha
# Processing Record 19 of Set 7 | braganca
# Processing Record 20 of Set 7 | aksarka
# Processing Record 21 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 7 | pandan
# Processing Record 24 of Set 7 | barcelona
# Processing Record 25 of Set 7 | izberbash
# Processing Record 26 of Set 7 | la esperanza
# Processing Record 27 of Set 7 | rognan
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | takestan
# Processing Record 30 of Set 7 | of
# City not found. Skipping...
# Processing Record 31 of Set 7 | batemans bay
# Processing Record 32 of Set 7 | lucapa
# Processing Record 33 of Set 7 | sao jose da laje
# Processing Record 34 of Set 7 | khovu-aksy
# Processing Record 35 of Set 7 | salalah
# Processing Record 36 of Set 7 | maldonado
# Processing Record 37 of Set 7 | tilichiki
# Processing Record 38 of Set 7 | eyl
# Processing Record 39 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | trairi
# Processing Record 42 of Set 7 | nokaneng
# Processing Record 43 of Set 7 | guerrero negro
# Processing Record 44 of Set 7 | missoula
# Processing Record 45 of Set 7 | havelock
# Processing Record 46 of Set 7 | zhadovka
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | dakar
# Processing Record 49 of Set 7 | beringovskiy
# Processing Record 50 of Set 7 | ugoofaaru
# Processing Record 1 of Set 8 | sistranda
# Processing Record 2 of Set 8 | mogadishu
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | odweyne
# Processing Record 5 of Set 8 | uray
# Processing Record 6 of Set 8 | serta
# Processing Record 7 of Set 8 | verkhnyaya toyma
# Processing Record 8 of Set 8 | north bend
# Processing Record 9 of Set 8 | ahipara
# Processing Record 10 of Set 8 | oytal
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | brae
# Processing Record 13 of Set 8 | murgab
# Processing Record 14 of Set 8 | blagoyevo
# Processing Record 15 of Set 8 | oksfjord
# Processing Record 16 of Set 8 | champerico
# Processing Record 17 of Set 8 | axim
# Processing Record 18 of Set 8 | larsnes
# Processing Record 19 of Set 8 | mackay
# Processing Record 20 of Set 8 | tuatapere
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | jalingo
# Processing Record 23 of Set 8 | antalaha
# Processing Record 24 of Set 8 | kyra
# Processing Record 25 of Set 8 | linhares
# Processing Record 26 of Set 8 | goderich
# Processing Record 27 of Set 8 | turhal
# Processing Record 28 of Set 8 | barra do garcas
# Processing Record 29 of Set 8 | abha
# Processing Record 30 of Set 8 | summerside
# Processing Record 31 of Set 8 | wilhelmshaven
# Processing Record 32 of Set 8 | los llanos de aridane
# Processing Record 33 of Set 8 | whitecourt
# Processing Record 34 of Set 8 | kurilsk
# Processing Record 35 of Set 8 | port moresby
# Processing Record 36 of Set 8 | banda aceh
# Processing Record 37 of Set 8 | ojinaga
# Processing Record 38 of Set 8 | pullman
# Processing Record 39 of Set 8 | itoman
# Processing Record 40 of Set 8 | westport
# Processing Record 41 of Set 8 | mananara
# Processing Record 42 of Set 8 | vangaindrano
# Processing Record 43 of Set 8 | mizan teferi
# Processing Record 44 of Set 8 | bukachacha
# Processing Record 45 of Set 8 | anloga
# Processing Record 46 of Set 8 | jutai
# Processing Record 47 of Set 8 | cuiluan
# Processing Record 48 of Set 8 | halifax
# Processing Record 49 of Set 8 | el sauzal
# Processing Record 50 of Set 8 | carballo
# Processing Record 1 of Set 9 | ilulissat
# Processing Record 2 of Set 9 | srednekolymsk
# Processing Record 3 of Set 9 | rio bonito
# Processing Record 4 of Set 9 | ajdabiya
# Processing Record 5 of Set 9 | shirochanka
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | port lincoln
# Processing Record 8 of Set 9 | numan
# Processing Record 9 of Set 9 | cape coast
# Processing Record 10 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 9 | carupano
# Processing Record 12 of Set 9 | sheridan
# Processing Record 13 of Set 9 | sandakan
# Processing Record 14 of Set 9 | sao joao da barra
# Processing Record 15 of Set 9 | kaseda
# Processing Record 16 of Set 9 | nsanje
# Processing Record 17 of Set 9 | hovd
# Processing Record 18 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 9 | baraboo
# Processing Record 20 of Set 9 | ndjole
# Processing Record 21 of Set 9 | onda
# Processing Record 22 of Set 9 | limbuhan
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | harindanga
# Processing Record 25 of Set 9 | seoul
# Processing Record 26 of Set 9 | jiexiu
# Processing Record 27 of Set 9 | barcelos
# Processing Record 28 of Set 9 | upernavik
# Processing Record 29 of Set 9 | whitehorse
# Processing Record 30 of Set 9 | isiro
# Processing Record 31 of Set 9 | elko
# Processing Record 32 of Set 9 | pathein
# Processing Record 33 of Set 9 | marica
# Processing Record 34 of Set 9 | toora-khem
# Processing Record 35 of Set 9 | ranong
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | severo-kurilsk
# Processing Record 38 of Set 9 | chuy
# Processing Record 39 of Set 9 | inyonga
# Processing Record 40 of Set 9 | alta floresta
# Processing Record 41 of Set 9 | te anau
# Processing Record 42 of Set 9 | atambua
# Processing Record 43 of Set 9 | gombong
# Processing Record 44 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 45 of Set 9 | tulsipur
# Processing Record 46 of Set 9 | wangqing
# Processing Record 47 of Set 9 | pochutla
# Processing Record 48 of Set 9 | mandalgovi
# Processing Record 49 of Set 9 | quelimane
# Processing Record 50 of Set 9 | kanbe
# Processing Record 1 of Set 10 | kormilovka
# Processing Record 2 of Set 10 | ayan
# Processing Record 3 of Set 10 | bogale
# Processing Record 4 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 10 | mocuba
# Processing Record 6 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 10 | touros
# Processing Record 8 of Set 10 | samfya
# Processing Record 9 of Set 10 | ribeira grande
# Processing Record 10 of Set 10 | fenoarivo atsinanana
# Processing Record 11 of Set 10 | jiangyou
# Processing Record 12 of Set 10 | honningsvag
# Processing Record 13 of Set 10 | yumen
# Processing Record 14 of Set 10 | pocone
# Processing Record 15 of Set 10 | whitefish
# Processing Record 16 of Set 10 | rustenburg
# Processing Record 17 of Set 10 | lentekhi
# Processing Record 18 of Set 10 | dawlatabad
# Processing Record 19 of Set 10 | guadalupe y calvo
# Processing Record 20 of Set 10 | biak
# Processing Record 21 of Set 10 | uzumlu
# City not found. Skipping...
# Processing Record 22 of Set 10 | savannah bight
# Processing Record 23 of Set 10 | rocha
# Processing Record 24 of Set 10 | sonoita
# Processing Record 25 of Set 10 | malakal
# Processing Record 26 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 10 | meulaboh
# Processing Record 28 of Set 10 | hamilton
# Processing Record 29 of Set 10 | kalakamati
# Processing Record 30 of Set 10 | urumqi
# Processing Record 31 of Set 10 | cidreira
# Processing Record 32 of Set 10 | homer
# Processing Record 33 of Set 10 | tabuk
# Processing Record 34 of Set 10 | matara
# Processing Record 35 of Set 10 | pimentel
# Processing Record 36 of Set 10 | carikar
# City not found. Skipping...
# Processing Record 37 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 10 | zdvinsk
# Processing Record 39 of Set 10 | uribia
# Processing Record 40 of Set 10 | ornskoldsvik
# Processing Record 41 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 42 of Set 10 | phan thiet
# Processing Record 43 of Set 10 | laguna
# Processing Record 44 of Set 10 | muros
# Processing Record 45 of Set 10 | clarence town
# Processing Record 46 of Set 10 | conceicao da barra
# Processing Record 47 of Set 10 | vuktyl
# Processing Record 48 of Set 10 | kungurtug
# Processing Record 49 of Set 10 | taldan
# Processing Record 50 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 11 | christchurch
# Processing Record 2 of Set 11 | marawi
# Processing Record 3 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 11 | vallenar
# Processing Record 5 of Set 11 | kashan
# Processing Record 6 of Set 11 | yeniseysk
# Processing Record 7 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 11 | alihe
# Processing Record 9 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 11 of Set 11 | indianola
# Processing Record 12 of Set 11 | plastun
# Processing Record 13 of Set 11 | tobe
# Processing Record 14 of Set 11 | talgar
# Processing Record 15 of Set 11 | sayville
# Processing Record 16 of Set 11 | tazovskiy
# Processing Record 17 of Set 11 | novyy urengoy
# Processing Record 18 of Set 11 | pauini
# Processing Record 19 of Set 11 | auki
# Processing Record 20 of Set 11 | adwa
# Processing Record 21 of Set 11 | najran
# Processing Record 22 of Set 11 | nisia floresta
# Processing Record 23 of Set 11 | banjar
# Processing Record 24 of Set 11 | massakory
# Processing Record 25 of Set 11 | almeirim
# Processing Record 26 of Set 11 | clonakilty
# Processing Record 27 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 11 | gazanjyk
# Processing Record 29 of Set 11 | marienburg
# Processing Record 30 of Set 11 | gusau
# Processing Record 31 of Set 11 | berikulskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | chadan
# Processing Record 33 of Set 11 | west bay
# Processing Record 34 of Set 11 | mahajanga
# Processing Record 35 of Set 11 | praia da vitoria
# Processing Record 36 of Set 11 | wajir
# Processing Record 37 of Set 11 | athgarh
# City not found. Skipping...
# Processing Record 38 of Set 11 | port macquarie
# Processing Record 39 of Set 11 | turukhansk
# Processing Record 40 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 11 | sesheke
# Processing Record 42 of Set 11 | ninghai
# Processing Record 43 of Set 11 | marsa matruh
# Processing Record 44 of Set 11 | juneau
# Processing Record 45 of Set 11 | tynne
# Processing Record 46 of Set 11 | dudinka
# Processing Record 47 of Set 11 | waitati
# Processing Record 48 of Set 11 | tessalit
# Processing Record 49 of Set 11 | poum
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | tambura
# Processing Record 2 of Set 12 | cholan
# City not found. Skipping...
# Processing Record 3 of Set 12 | barranca
# Processing Record 4 of Set 12 | fortuna
# Processing Record 5 of Set 12 | narathiwat
# Processing Record 6 of Set 12 | muroto
# Processing Record 7 of Set 12 | kalmunai
# Processing Record 8 of Set 12 | kismayo
# Processing Record 9 of Set 12 | portland
# Processing Record 10 of Set 12 | poltavka
# Processing Record 11 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 12 | road town
# Processing Record 13 of Set 12 | hualmay
# Processing Record 14 of Set 12 | porto santo
# Processing Record 15 of Set 12 | kargopol
# Processing Record 16 of Set 12 | svetlyy
# Processing Record 17 of Set 12 | puerto del rosario
# Processing Record 18 of Set 12 | lipari
# Processing Record 19 of Set 12 | atlantic city
# Processing Record 20 of Set 12 | dergachi
# Processing Record 21 of Set 12 | martapura
# Processing Record 22 of Set 12 | ngunguru
# Processing Record 23 of Set 12 | bridlington
# Processing Record 24 of Set 12 | lazaro cardenas
# Processing Record 25 of Set 12 | khonsa
# Processing Record 26 of Set 12 | oussouye
# Processing Record 27 of Set 12 | lodja
# Processing Record 28 of Set 12 | san cristobal
# Processing Record 29 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 12 | bac lieu
# Processing Record 31 of Set 12 | nemuro
# Processing Record 32 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 12 | tarragona
# Processing Record 34 of Set 12 | sao filipe
# Processing Record 35 of Set 12 | naushki
# Processing Record 36 of Set 12 | kontagora
# Processing Record 37 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 38 of Set 12 | saint-leu
# Processing Record 39 of Set 12 | kamenka
# Processing Record 40 of Set 12 | samarai
# Processing Record 41 of Set 12 | ashqelon
# Processing Record 42 of Set 12 | lukulu
# Processing Record 43 of Set 12 | vilyuysk
# Processing Record 44 of Set 12 | piet retief
# Processing Record 45 of Set 12 | opuwo
# Processing Record 46 of Set 12 | viedma
# Processing Record 47 of Set 12 | belgrade
# Processing Record 48 of Set 12 | vicosa
# Processing Record 49 of Set 12 | acajutla
# Processing Record 50 of Set 12 | dali
# Processing Record 1 of Set 13 | kathmandu
# Processing Record 2 of Set 13 | san ramon
# Processing Record 3 of Set 13 | blois
# Processing Record 4 of Set 13 | alyangula
# Processing Record 5 of Set 13 | qasigiannguit
# Processing Record 6 of Set 13 | sangar
# Processing Record 7 of Set 13 | verkhnevilyuysk
# Processing Record 8 of Set 13 | riberalta
# Processing Record 9 of Set 13 | dumka
# Processing Record 10 of Set 13 | ejura
# Processing Record 11 of Set 13 | mabaruma
# Processing Record 12 of Set 13 | chingirlau
# Processing Record 13 of Set 13 | marathon
# Processing Record 14 of Set 13 | mahibadhoo
# Processing Record 15 of Set 13 | ketchikan
# Processing Record 16 of Set 13 | igarka
# Processing Record 17 of Set 13 | breisach
# Processing Record 18 of Set 13 | avera
# Processing Record 19 of Set 13 | dekar
# Processing Record 20 of Set 13 | caravelas
# Processing Record 21 of Set 13 | lakes entrance
# Processing Record 22 of Set 13 | eastbourne
# Processing Record 23 of Set 13 | half moon bay
# Processing Record 24 of Set 13 | barinas
# Processing Record 25 of Set 13 | faro
# Processing Record 26 of Set 13 | jizan
# Processing Record 27 of Set 13 | cap-aux-meules
# Processing Record 28 of Set 13 | dingle
# Processing Record 29 of Set 13 | andenes
# Processing Record 30 of Set 13 | emerald
# Processing Record 31 of Set 13 | okhotsk
# Processing Record 32 of Set 13 | lamu
# Processing Record 33 of Set 13 | kerman
# Processing Record 34 of Set 13 | mitzic
# Processing Record 35 of Set 13 | sechura
# Processing Record 36 of Set 13 | flinders
# Processing Record 37 of Set 13 | wakkanai
# Processing Record 38 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 13 | wolsztyn
# Processing Record 40 of Set 13 | newport
# Processing Record 41 of Set 13 | sergeyevka
# Processing Record 42 of Set 13 | kautokeino
# Processing Record 43 of Set 13 | pingzhuang
# Processing Record 44 of Set 13 | kosikha
# Processing Record 45 of Set 13 | astana
# Processing Record 46 of Set 13 | niquero
# Processing Record 47 of Set 13 | neosho
# Processing Record 48 of Set 13 | kantang
# Processing Record 49 of Set 13 | port-de-bouc
# Processing Record 50 of Set 13 | labuan
# Processing Record 1 of Set 14 | santiago del estero
# Processing Record 2 of Set 14 | pimenta bueno
# Processing Record 3 of Set 14 | dubbo
# Processing Record 4 of Set 14 | acarau
# Processing Record 5 of Set 14 | cukai
# Processing Record 6 of Set 14 | moose factory
# Processing Record 7 of Set 14 | general pico
# Processing Record 8 of Set 14 | necochea
# Processing Record 9 of Set 14 | kudahuvadhoo
# Processing Record 10 of Set 14 | jumla
# Processing Record 11 of Set 14 | ventspils
# Processing Record 12 of Set 14 | egvekinot
# Processing Record 13 of Set 14 | casimiro castillo
# Processing Record 14 of Set 14 | bouca
# Processing Record 15 of Set 14 | bow island
# Processing Record 16 of Set 14 | kalianget
# Processing Record 17 of Set 14 | college
# Processing Record 18 of Set 14 | hazorasp
# Processing Record 19 of Set 14 | vestmannaeyjar
# Processing Record 20 of Set 14 | olot
# Processing Record 21 of Set 14 | zhigansk
# Processing Record 22 of Set 14 | rivadavia
# Processing Record 23 of Set 14 | iwanai
# Processing Record 24 of Set 14 | mattawa
# Processing Record 25 of Set 14 | hervey bay
# Processing Record 26 of Set 14 | oromocto
# Processing Record 27 of Set 14 | comodoro rivadavia
# Processing Record 28 of Set 14 | vardo
# Processing Record 29 of Set 14 | luyang
# Processing Record 30 of Set 14 | domoni
# Processing Record 31 of Set 14 | komsomolskiy
# Processing Record 32 of Set 14 | lavrentiya
# Processing Record 33 of Set 14 | great yarmouth
# Processing Record 34 of Set 14 | markala
# Processing Record 35 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 14 | guantanamo
# Processing Record 37 of Set 14 | puerto narino
# Processing Record 38 of Set 14 | poli
# Processing Record 39 of Set 14 | sambava
# Processing Record 40 of Set 14 | coquimbo
# Processing Record 41 of Set 14 | lakselv
# Processing Record 42 of Set 14 | inuvik
# Processing Record 43 of Set 14 | sindor
# Processing Record 44 of Set 14 | sotnikovskoye
# Processing Record 45 of Set 14 | kamina
# Processing Record 46 of Set 14 | parbatipur
# Processing Record 47 of Set 14 | montgomery
# Processing Record 48 of Set 14 | beaufort
# Processing Record 49 of Set 14 | diofior
# Processing Record 50 of Set 14 | marmaris
# Processing Record 1 of Set 15 | lovozero
# Processing Record 2 of Set 15 | carutapera
# Processing Record 3 of Set 15 | bousso
# Processing Record 4 of Set 15 | galveston
# Processing Record 5 of Set 15 | guider
# Processing Record 6 of Set 15 | sweetwater
# Processing Record 7 of Set 15 | xining
# Processing Record 8 of Set 15 | villa bruzual
# Processing Record 9 of Set 15 | kushiro
# Processing Record 10 of Set 15 | nago
# Processing Record 11 of Set 15 | terrace
# Processing Record 12 of Set 15 | el jicaro
# Processing Record 13 of Set 15 | vestmanna
# Processing Record 14 of Set 15 | kiunga
# Processing Record 15 of Set 15 | issoire
# Processing Record 16 of Set 15 | muisne
# Processing Record 17 of Set 15 | kutum
# Processing Record 18 of Set 15 | camacupa
# Processing Record 19 of Set 15 | berdigestyakh
# Processing Record 20 of Set 15 | havoysund
# Processing Record 21 of Set 15 | colac
# Processing Record 22 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 15 | yanam
# Processing Record 24 of Set 15 | negele
# City not found. Skipping...
# Processing Record 25 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 15 | san luis
# Processing Record 27 of Set 15 | liyang
# Processing Record 28 of Set 15 | herne bay
# Processing Record 29 of Set 15 | bolivar
# Processing Record 30 of Set 15 | esil
# Processing Record 31 of Set 15 | noumea
# Processing Record 32 of Set 15 | guozhen
# Processing Record 33 of Set 15 | padang
# Processing Record 34 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 15 | olive branch
# Processing Record 36 of Set 15 | abonnema
# Processing Record 37 of Set 15 | lismore
# Processing Record 38 of Set 15 | nelson bay
# Processing Record 39 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 15 | conchas
# Processing Record 41 of Set 15 | heilbron
# Processing Record 42 of Set 15 | korablino
# Processing Record 43 of Set 15 | vila
# Processing Record 44 of Set 15 | geraldton
# Processing Record 45 of Set 15 | sitka
# Processing Record 46 of Set 15 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 47 of Set 15 | tenenkou
# Processing Record 48 of Set 15 | sisimiut
# Processing Record 49 of Set 15 | conceicao do araguaia
# Processing Record 50 of Set 15 | paamiut
# Processing Record 1 of Set 16 | ganzhou
# Processing Record 2 of Set 16 | jinzhou
# Processing Record 3 of Set 16 | santa fe
# Processing Record 4 of Set 16 | kurdzhinovo
# Processing Record 5 of Set 16 | port-gentil
# Processing Record 6 of Set 16 | champasak
# Processing Record 7 of Set 16 | marquette
# Processing Record 8 of Set 16 | plouzane
# Processing Record 9 of Set 16 | cumana
# Processing Record 10 of Set 16 | severnoye
# Processing Record 11 of Set 16 | key largo
# Processing Record 12 of Set 16 | leshukonskoye
# Processing Record 13 of Set 16 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 16 | novo aripuana
# Processing Record 15 of Set 16 | espanola
# Processing Record 16 of Set 16 | manzanillo
# Processing Record 17 of Set 16 | ahtopol
# Processing Record 18 of Set 16 | krasnokamensk
# Processing Record 19 of Set 16 | jahrom
# City not found. Skipping...
# Processing Record 20 of Set 16 | dakoro
# Processing Record 21 of Set 16 | lasa
# Processing Record 22 of Set 16 | deputatskiy
# Processing Record 23 of Set 16 | port blair
# Processing Record 24 of Set 16 | dingzhou
# Processing Record 25 of Set 16 | pishin
# Processing Record 26 of Set 16 | antofagasta
# Processing Record 27 of Set 16 | erzincan
# Processing Record 28 of Set 16 | napier
# Processing Record 29 of Set 16 | birao
# Processing Record 30 of Set 16 | ostrovnoy
# Processing Record 31 of Set 16 | digha
# Processing Record 32 of Set 16 | inta
# Processing Record 33 of Set 16 | waddan
# Processing Record 34 of Set 16 | anahuac
# Processing Record 35 of Set 16 | pontarlier
# Processing Record 36 of Set 16 | bakel
# Processing Record 37 of Set 16 | nehe
# Processing Record 38 of Set 16 | sabana grande de boya
# Processing Record 39 of Set 16 | udachnyy
# Processing Record 40 of Set 16 | tinaquillo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Butaritari   3.0707  172.7902     81.16        75          14
# 1                   Jijiga   9.3500   42.8000     63.61        61          57
# 2             Punta Arenas -53.1500  -70.9167     42.91        56           0
# 3                  Rikitea -23.1203 -134.9692     70.63        71           4
# 4                   Rudbar  30.1500   62.6000     86.20        14           0
# ..                     ...      ...       ...       ...       ...         ...
# 722                  Bakel  14.9050  -12.4568     88.88        56          56
# 723                   Nehe  48.4833  124.8333     56.77        95         100
# 724  Sabana Grande De Boya  18.9450  -69.7933     86.50        77          45
# 725               Udachnyy  66.4167  112.4000     62.15        42           6
# 726             Tinaquillo   9.9186  -68.3047     79.29        80          74
#
#      Wind Speed Country Weather Description
# 0          6.04      KI          few clouds
# 1         16.80      ET       broken clouds
# 2         16.11      CL           clear sky
# 3          9.89      PF           clear sky
# 4         12.03      AF           clear sky
# ..          ...     ...                 ...
# 722        4.45      SN       broken clouds
# 723       11.59      CN     overcast clouds
# 724        7.20      DO    scattered clouds
# 725        5.17      RU           clear sky
# 726        5.73      VE       broken clouds
#
# [727 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Butaritari      KI   3.0707  172.7902     81.16        75          14
# 1           Jijiga      ET   9.3500   42.8000     63.61        61          57
# 2     Punta Arenas      CL -53.1500  -70.9167     42.91        56           0
# 3          Rikitea      PF -23.1203 -134.9692     70.63        71           4
# 4           Rudbar      AF  30.1500   62.6000     86.20        14           0
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     69.76        94          75
# 6           Semnan      IR  35.5729   53.3971     82.15        36          45
# 7           Mandan      US  46.8267 -100.8896     88.02        31          20
# 8             Lebu      CL -37.6167  -73.6500     51.91        68           0
# 9           Agadir      MA  30.4202   -9.5982     77.45        59           2
#
#    Wind Speed Weather Description
# 0        6.04          few clouds
# 1       16.80       broken clouds
# 2       16.11           clear sky
# 3        9.89           clear sky
# 4       12.03           clear sky
# 5        3.44       broken clouds
# 6        7.65    scattered clouds
# 7        5.75                haze
# 8       15.70           clear sky
# 9        4.74           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
