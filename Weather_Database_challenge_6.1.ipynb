# %% [markdown]
# # challenge 6 Deliverable 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities. To store cities names
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. Ask Mark
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities. Ask Mark
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description
                          #"Date": city_date
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | tautira
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | kushima
# Processing Record 10 of Set 1 | longyearbyen
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | hambantota
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | tilichiki
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | eydhafushi
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | longview
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | sredec
# City not found. Skipping...
# Processing Record 26 of Set 1 | svetlyy
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | ilhabela
# Processing Record 31 of Set 1 | lakhdenpokhya
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | george
# Processing Record 37 of Set 1 | ahipara
# Processing Record 38 of Set 1 | port hardy
# Processing Record 39 of Set 1 | alofi
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | kabalo
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | umm lajj
# Processing Record 46 of Set 1 | halifax
# Processing Record 47 of Set 1 | truth or consequences
# Processing Record 48 of Set 1 | sorochinsk
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | matara
# Processing Record 1 of Set 2 | blatec
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | bogorodskoye
# Processing Record 4 of Set 2 | inverell
# Processing Record 5 of Set 2 | vao
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | seydi
# Processing Record 9 of Set 2 | vila
# Processing Record 10 of Set 2 | loreto
# Processing Record 11 of Set 2 | yar-sale
# Processing Record 12 of Set 2 | bathsheba
# Processing Record 13 of Set 2 | ancud
# Processing Record 14 of Set 2 | denpasar
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | khasan
# Processing Record 21 of Set 2 | aykhal
# Processing Record 22 of Set 2 | walvis bay
# Processing Record 23 of Set 2 | omboue
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | shingu
# Processing Record 27 of Set 2 | la orilla
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 2 | namatanai
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | iralaya
# Processing Record 33 of Set 2 | kiruna
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | dzhebariki-khaya
# Processing Record 37 of Set 2 | tres arroyos
# Processing Record 38 of Set 2 | bang khla
# Processing Record 39 of Set 2 | ponferrada
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | broken hill
# Processing Record 42 of Set 2 | pemangkat
# Processing Record 43 of Set 2 | rikitea
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | sobolevo
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | akyab
# Processing Record 49 of Set 2 | sola
# Processing Record 50 of Set 2 | damnoen saduak
# Processing Record 1 of Set 3 | raudeberg
# Processing Record 2 of Set 3 | mabaruma
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | sao luis de montes belos
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | chemax
# Processing Record 7 of Set 3 | shache
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | komsomolskiy
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | svetlaya
# Processing Record 14 of Set 3 | mahanje
# Processing Record 15 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 16 of Set 3 | geraldton
# Processing Record 17 of Set 3 | lorengau
# Processing Record 18 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 3 | chernolesskoye
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | tsumeb
# Processing Record 22 of Set 3 | saskylakh
# Processing Record 23 of Set 3 | sumbawanga
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | divnomorskoye
# Processing Record 28 of Set 3 | lamar
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | bintulu
# Processing Record 31 of Set 3 | dire dawa
# Processing Record 32 of Set 3 | springbok
# Processing Record 33 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 3 | te anau
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | pangnirtung
# Processing Record 37 of Set 3 | flinders
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | muniz freire
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | henties bay
# Processing Record 42 of Set 3 | emerald
# Processing Record 43 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 3 | zyryanovsk
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | jaciara
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | karratha
# Processing Record 50 of Set 3 | thinadhoo
# Processing Record 1 of Set 4 | ekibastuz
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | adrar
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | aksu
# Processing Record 7 of Set 4 | paine
# Processing Record 8 of Set 4 | ostersund
# Processing Record 9 of Set 4 | den helder
# Processing Record 10 of Set 4 | blenheim
# Processing Record 11 of Set 4 | sapao
# City not found. Skipping...
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | lumphat
# Processing Record 14 of Set 4 | manali
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | flagstaff
# Processing Record 17 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 4 | poum
# Processing Record 19 of Set 4 | trapani
# Processing Record 20 of Set 4 | taoudenni
# Processing Record 21 of Set 4 | srandakan
# Processing Record 22 of Set 4 | nyimba
# Processing Record 23 of Set 4 | zhicheng
# Processing Record 24 of Set 4 | ishinomaki
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | rio grande
# Processing Record 27 of Set 4 | ambovombe
# Processing Record 28 of Set 4 | chara
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | los llanos de aridane
# Processing Record 33 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 4 | santa rosa
# Processing Record 35 of Set 4 | whitehorse
# Processing Record 36 of Set 4 | huangnihe
# Processing Record 37 of Set 4 | senno
# Processing Record 38 of Set 4 | stillwater
# Processing Record 39 of Set 4 | winchester
# Processing Record 40 of Set 4 | harnosand
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | port alfred
# Processing Record 43 of Set 4 | billings
# Processing Record 44 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 4 | narsaq
# Processing Record 46 of Set 4 | fuerte
# Processing Record 47 of Set 4 | goderich
# Processing Record 48 of Set 4 | phalodi
# Processing Record 49 of Set 4 | faanui
# Processing Record 50 of Set 4 | havelock
# Processing Record 1 of Set 5 | ascension
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | dingle
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | najran
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | korem
# Processing Record 8 of Set 5 | ilulissat
# Processing Record 9 of Set 5 | lata
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | qiongshan
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | covington
# Processing Record 14 of Set 5 | beisfjord
# Processing Record 15 of Set 5 | puttur
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | hobyo
# Processing Record 18 of Set 5 | itoman
# Processing Record 19 of Set 5 | bajitpur
# Processing Record 20 of Set 5 | aksarka
# Processing Record 21 of Set 5 | porbandar
# Processing Record 22 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 5 | brae
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | bose
# Processing Record 27 of Set 5 | bilma
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | kikwit
# Processing Record 30 of Set 5 | sao filipe
# Processing Record 31 of Set 5 | finnsnes
# Processing Record 32 of Set 5 | kemijarvi
# Processing Record 33 of Set 5 | tabas
# Processing Record 34 of Set 5 | aitape
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | roura
# Processing Record 37 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 5 | rawson
# Processing Record 39 of Set 5 | namibe
# Processing Record 40 of Set 5 | peniche
# Processing Record 41 of Set 5 | qasigiannguit
# Processing Record 42 of Set 5 | chulman
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | la palma
# Processing Record 45 of Set 5 | kargil
# Processing Record 46 of Set 5 | saldanha
# Processing Record 47 of Set 5 | sao joao da barra
# Processing Record 48 of Set 5 | ambilobe
# Processing Record 49 of Set 5 | caledonia
# Processing Record 50 of Set 5 | west bay
# Processing Record 1 of Set 6 | hokitika
# Processing Record 2 of Set 6 | kota belud
# Processing Record 3 of Set 6 | yithion
# City not found. Skipping...
# Processing Record 4 of Set 6 | krasnoselkup
# Processing Record 5 of Set 6 | kalabo
# Processing Record 6 of Set 6 | pevek
# Processing Record 7 of Set 6 | saint-augustin
# Processing Record 8 of Set 6 | chicama
# Processing Record 9 of Set 6 | virginia beach
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | honiara
# Processing Record 12 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 6 | buraydah
# Processing Record 14 of Set 6 | bani
# Processing Record 15 of Set 6 | port moresby
# Processing Record 16 of Set 6 | yenagoa
# Processing Record 17 of Set 6 | tullahoma
# Processing Record 18 of Set 6 | samarinda
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | bonham
# Processing Record 21 of Set 6 | baherden
# Processing Record 22 of Set 6 | labuhan
# Processing Record 23 of Set 6 | bubaque
# Processing Record 24 of Set 6 | pak phanang
# Processing Record 25 of Set 6 | belford roxo
# Processing Record 26 of Set 6 | camacupa
# Processing Record 27 of Set 6 | russell
# Processing Record 28 of Set 6 | east london
# Processing Record 29 of Set 6 | high prairie
# Processing Record 30 of Set 6 | marawi
# Processing Record 31 of Set 6 | zhigansk
# Processing Record 32 of Set 6 | olafsvik
# Processing Record 33 of Set 6 | beringovskiy
# Processing Record 34 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 6 | chabahar
# Processing Record 36 of Set 6 | rio cuarto
# Processing Record 37 of Set 6 | naftalan
# Processing Record 38 of Set 6 | itarema
# Processing Record 39 of Set 6 | berdigestyakh
# Processing Record 40 of Set 6 | jian
# Processing Record 41 of Set 6 | barrhead
# Processing Record 42 of Set 6 | santa isabel do rio negro
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | port elizabeth
# Processing Record 45 of Set 6 | northam
# Processing Record 46 of Set 6 | acajutla
# Processing Record 47 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 6 | agirish
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 6 | havoysund
# Processing Record 1 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | kaeo
# Processing Record 4 of Set 7 | cabra
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | chingirlau
# Processing Record 7 of Set 7 | bollnas
# Processing Record 8 of Set 7 | cerrito
# Processing Record 9 of Set 7 | pundaguitan
# Processing Record 10 of Set 7 | grindavik
# Processing Record 11 of Set 7 | hamilton
# Processing Record 12 of Set 7 | sandwick
# Processing Record 13 of Set 7 | kinablangan
# Processing Record 14 of Set 7 | saurimo
# Processing Record 15 of Set 7 | nyurba
# Processing Record 16 of Set 7 | portlethen
# Processing Record 17 of Set 7 | kerman
# Processing Record 18 of Set 7 | barcelos
# Processing Record 19 of Set 7 | egvekinot
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | roald
# Processing Record 23 of Set 7 | niquelandia
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | surin
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | keffi
# Processing Record 28 of Set 7 | marsh harbour
# Processing Record 29 of Set 7 | ketchikan
# Processing Record 30 of Set 7 | bilibino
# Processing Record 31 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 7 | ouadda
# Processing Record 33 of Set 7 | show low
# Processing Record 34 of Set 7 | tampakan
# Processing Record 35 of Set 7 | loa janan
# Processing Record 36 of Set 7 | mitsamiouli
# Processing Record 37 of Set 7 | saint-joseph
# Processing Record 38 of Set 7 | eirunepe
# Processing Record 39 of Set 7 | dalinghe
# City not found. Skipping...
# Processing Record 40 of Set 7 | biltine
# Processing Record 41 of Set 7 | marquette
# Processing Record 42 of Set 7 | terrace bay
# Processing Record 43 of Set 7 | shenjiamen
# Processing Record 44 of Set 7 | suntar
# Processing Record 45 of Set 7 | belaya gora
# Processing Record 46 of Set 7 | eskisehir
# Processing Record 47 of Set 7 | noumea
# Processing Record 48 of Set 7 | hare bay
# Processing Record 49 of Set 7 | hirara
# Processing Record 50 of Set 7 | bushenyi
# Processing Record 1 of Set 8 | sarankhola
# Processing Record 2 of Set 8 | pontiac
# Processing Record 3 of Set 8 | vredendal
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | trairi
# Processing Record 6 of Set 8 | aklavik
# Processing Record 7 of Set 8 | vostok
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | hays
# Processing Record 10 of Set 8 | kalmunai
# Processing Record 11 of Set 8 | catarama
# Processing Record 12 of Set 8 | butag
# Processing Record 13 of Set 8 | puerto maldonado
# Processing Record 14 of Set 8 | esik
# Processing Record 15 of Set 8 | naruja
# Processing Record 16 of Set 8 | saint andrews
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | molochnyy
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | margherita
# Processing Record 22 of Set 8 | viedma
# Processing Record 23 of Set 8 | rio gallegos
# Processing Record 24 of Set 8 | ignalina
# Processing Record 25 of Set 8 | carutapera
# Processing Record 26 of Set 8 | ucluelet
# Processing Record 27 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 8 | tayoltita
# Processing Record 29 of Set 8 | nador
# Processing Record 30 of Set 8 | volovo
# Processing Record 31 of Set 8 | coihaique
# Processing Record 32 of Set 8 | rurrenabaque
# Processing Record 33 of Set 8 | tambopata
# Processing Record 34 of Set 8 | luorong
# Processing Record 35 of Set 8 | oistins
# Processing Record 36 of Set 8 | constitucion
# Processing Record 37 of Set 8 | vanimo
# Processing Record 38 of Set 8 | kyshtovka
# Processing Record 39 of Set 8 | korla
# Processing Record 40 of Set 8 | iracoubo
# Processing Record 41 of Set 8 | kirakira
# Processing Record 42 of Set 8 | raahe
# Processing Record 43 of Set 8 | santa maria
# Processing Record 44 of Set 8 | zhangye
# Processing Record 45 of Set 8 | lipno
# Processing Record 46 of Set 8 | comodoro rivadavia
# Processing Record 47 of Set 8 | jardim
# Processing Record 48 of Set 8 | cap malheureux
# Processing Record 49 of Set 8 | khuzhir
# Processing Record 50 of Set 8 | okha
# Processing Record 1 of Set 9 | ribeira brava
# Processing Record 2 of Set 9 | laja
# Processing Record 3 of Set 9 | magistralnyy
# Processing Record 4 of Set 9 | gardez
# Processing Record 5 of Set 9 | seymchan
# Processing Record 6 of Set 9 | mogadishu
# Processing Record 7 of Set 9 | vila franca do campo
# Processing Record 8 of Set 9 | manokwari
# Processing Record 9 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 9 | kayes
# Processing Record 11 of Set 9 | necochea
# Processing Record 12 of Set 9 | gezing
# Processing Record 13 of Set 9 | polovinnoye
# Processing Record 14 of Set 9 | casper
# Processing Record 15 of Set 9 | ormara
# Processing Record 16 of Set 9 | togur
# Processing Record 17 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 18 of Set 9 | lisakovsk
# Processing Record 19 of Set 9 | ca mau
# Processing Record 20 of Set 9 | nchelenge
# Processing Record 21 of Set 9 | lakes entrance
# Processing Record 22 of Set 9 | zdvinsk
# Processing Record 23 of Set 9 | fredericksburg
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | sechura
# Processing Record 26 of Set 9 | seoul
# Processing Record 27 of Set 9 | warri
# Processing Record 28 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 9 | dudinka
# Processing Record 30 of Set 9 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 31 of Set 9 | sept-iles
# Processing Record 32 of Set 9 | klaksvik
# Processing Record 33 of Set 9 | tucumcari
# Processing Record 34 of Set 9 | powell river
# Processing Record 35 of Set 9 | nizwa
# Processing Record 36 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 9 | songkhla
# Processing Record 38 of Set 9 | isangel
# Processing Record 39 of Set 9 | ngunguru
# Processing Record 40 of Set 9 | atherton
# Processing Record 41 of Set 9 | arandis
# Processing Record 42 of Set 9 | mayumba
# Processing Record 43 of Set 9 | sisimiut
# Processing Record 44 of Set 9 | strelka
# Processing Record 45 of Set 9 | houma
# Processing Record 46 of Set 9 | uruzgan
# Processing Record 47 of Set 9 | hohhot
# Processing Record 48 of Set 9 | san rafael
# Processing Record 49 of Set 9 | broome
# Processing Record 50 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 10 | douglas
# Processing Record 2 of Set 10 | doha
# Processing Record 3 of Set 10 | vrangel
# Processing Record 4 of Set 10 | gushikawa
# Processing Record 5 of Set 10 | kintinku
# Processing Record 6 of Set 10 | dongkan
# Processing Record 7 of Set 10 | luba
# Processing Record 8 of Set 10 | cabo rojo
# Processing Record 9 of Set 10 | mangrol
# Processing Record 10 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 11 of Set 10 | souillac
# Processing Record 12 of Set 10 | ballina
# Processing Record 13 of Set 10 | nantucket
# Processing Record 14 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 10 | baykit
# Processing Record 16 of Set 10 | puerto leguizamo
# Processing Record 17 of Set 10 | beni suef
# Processing Record 18 of Set 10 | mizdah
# Processing Record 19 of Set 10 | kununurra
# Processing Record 20 of Set 10 | cairns
# Processing Record 21 of Set 10 | islamkot
# Processing Record 22 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 10 | baijiantan
# Processing Record 24 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 10 | tiznit
# Processing Record 27 of Set 10 | sonoita
# Processing Record 28 of Set 10 | fortuna
# Processing Record 29 of Set 10 | bjala
# City not found. Skipping...
# Processing Record 30 of Set 10 | robertsport
# Processing Record 31 of Set 10 | novyy urengoy
# Processing Record 32 of Set 10 | vicuna
# Processing Record 33 of Set 10 | sinnamary
# Processing Record 34 of Set 10 | mullovka
# Processing Record 35 of Set 10 | plettenberg bay
# Processing Record 36 of Set 10 | kholuy
# Processing Record 37 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 38 of Set 10 | kudahuvadhoo
# Processing Record 39 of Set 10 | musafirkhana
# Processing Record 40 of Set 10 | andover
# Processing Record 41 of Set 10 | ponta delgada
# Processing Record 42 of Set 10 | podosinovets
# Processing Record 43 of Set 10 | prince george
# Processing Record 44 of Set 10 | amalapuram
# Processing Record 45 of Set 10 | harper
# Processing Record 46 of Set 10 | nioro
# Processing Record 47 of Set 10 | sishui
# Processing Record 48 of Set 10 | sorland
# Processing Record 49 of Set 10 | grand gaube
# Processing Record 50 of Set 10 | boma
# Processing Record 1 of Set 11 | progreso
# Processing Record 2 of Set 11 | yarkovo
# Processing Record 3 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 11 | barabai
# Processing Record 5 of Set 11 | mahon
# Processing Record 6 of Set 11 | dakar
# Processing Record 7 of Set 11 | katima mulilo
# Processing Record 8 of Set 11 | tottori
# Processing Record 9 of Set 11 | santa maria del oro
# Processing Record 10 of Set 11 | kokstad
# Processing Record 11 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 12 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 11 | kapuskasing
# Processing Record 14 of Set 11 | minatitlan
# Processing Record 15 of Set 11 | nagato
# Processing Record 16 of Set 11 | ewa beach
# Processing Record 17 of Set 11 | paamiut
# Processing Record 18 of Set 11 | pervomayskoye
# Processing Record 19 of Set 11 | san cristobal
# Processing Record 20 of Set 11 | payo
# Processing Record 21 of Set 11 | makueni
# Processing Record 22 of Set 11 | yerbogachen
# Processing Record 23 of Set 11 | olhao
# Processing Record 24 of Set 11 | mandla
# Processing Record 25 of Set 11 | morehead
# Processing Record 26 of Set 11 | bolivar
# Processing Record 27 of Set 11 | tam ky
# Processing Record 28 of Set 11 | lazaro cardenas
# Processing Record 29 of Set 11 | ibotirama
# Processing Record 30 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 11 | scotts valley
# Processing Record 32 of Set 11 | barra patuca
# Processing Record 33 of Set 11 | kuching
# Processing Record 34 of Set 11 | nome
# Processing Record 35 of Set 11 | lamu
# Processing Record 36 of Set 11 | mumbwa
# Processing Record 37 of Set 11 | champerico
# Processing Record 38 of Set 11 | nizhniy tsasuchey
# Processing Record 39 of Set 11 | yinchuan
# Processing Record 40 of Set 11 | kashi
# Processing Record 41 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 11 | esso
# Processing Record 43 of Set 11 | talaya
# Processing Record 44 of Set 11 | zhangjiakou
# Processing Record 45 of Set 11 | atar
# Processing Record 46 of Set 11 | margate
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | dondo
# Processing Record 49 of Set 11 | pulandian
# Processing Record 50 of Set 11 | salalah
# Processing Record 1 of Set 12 | batagay
# Processing Record 2 of Set 12 | balud
# Processing Record 3 of Set 12 | djibo
# Processing Record 4 of Set 12 | axim
# Processing Record 5 of Set 12 | yulara
# Processing Record 6 of Set 12 | igarka
# Processing Record 7 of Set 12 | kuanshan
# City not found. Skipping...
# Processing Record 8 of Set 12 | yarim
# Processing Record 9 of Set 12 | nouakchott
# Processing Record 10 of Set 12 | abu samrah
# Processing Record 11 of Set 12 | muroto
# Processing Record 12 of Set 12 | inuvik
# Processing Record 13 of Set 12 | hualmay
# Processing Record 14 of Set 12 | caraballeda
# Processing Record 15 of Set 12 | tura
# Processing Record 16 of Set 12 | dryden
# Processing Record 17 of Set 12 | aswan
# Processing Record 18 of Set 12 | quatre cocos
# Processing Record 19 of Set 12 | saint-anselme
# Processing Record 20 of Set 12 | varna
# Processing Record 21 of Set 12 | segou
# Processing Record 22 of Set 12 | eenhana
# Processing Record 23 of Set 12 | mingyue
# Processing Record 24 of Set 12 | rehoboth
# Processing Record 25 of Set 12 | oranjemund
# Processing Record 26 of Set 12 | glencoe
# Processing Record 27 of Set 12 | nabire
# Processing Record 28 of Set 12 | batagay-alyta
# Processing Record 29 of Set 12 | lufilufi
# Processing Record 30 of Set 12 | half moon bay
# Processing Record 31 of Set 12 | inhambane
# Processing Record 32 of Set 12 | oswego
# Processing Record 33 of Set 12 | miles city
# Processing Record 34 of Set 12 | ayolas
# Processing Record 35 of Set 12 | zalari
# Processing Record 36 of Set 12 | maple creek
# Processing Record 37 of Set 12 | osorno
# Processing Record 38 of Set 12 | paka
# Processing Record 39 of Set 12 | tezu
# Processing Record 40 of Set 12 | puerto del rosario
# Processing Record 41 of Set 12 | miramar
# Processing Record 42 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 43 of Set 12 | sertanopolis
# Processing Record 44 of Set 12 | launceston
# Processing Record 45 of Set 12 | bahia blanca
# Processing Record 46 of Set 12 | hovd
# Processing Record 47 of Set 12 | ugoofaaru
# Processing Record 48 of Set 12 | pashiya
# Processing Record 49 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 50 of Set 12 | floro
# Processing Record 1 of Set 13 | naryan-mar
# Processing Record 2 of Set 13 | pishva
# Processing Record 3 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 13 | kathmandu
# Processing Record 5 of Set 13 | liepaja
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | saint george
# Processing Record 8 of Set 13 | rudsar
# Processing Record 9 of Set 13 | awjilah
# Processing Record 10 of Set 13 | semey
# Processing Record 11 of Set 13 | sitka
# Processing Record 12 of Set 13 | mahonda
# Processing Record 13 of Set 13 | bhadra
# Processing Record 14 of Set 13 | oshkosh
# Processing Record 15 of Set 13 | hvide sande
# Processing Record 16 of Set 13 | biak
# Processing Record 17 of Set 13 | eyl
# Processing Record 18 of Set 13 | haines junction
# Processing Record 19 of Set 13 | jalu
# Processing Record 20 of Set 13 | visnes
# Processing Record 21 of Set 13 | canton
# Processing Record 22 of Set 13 | young
# Processing Record 23 of Set 13 | bitam
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | college
# Processing Record 26 of Set 13 | bahar
# Processing Record 27 of Set 13 | staryy nadym
# Processing Record 28 of Set 13 | codrington
# Processing Record 29 of Set 13 | beyneu
# Processing Record 30 of Set 13 | dinguiraye
# Processing Record 31 of Set 13 | glace bay
# Processing Record 32 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 13 | novita
# Processing Record 34 of Set 13 | kampong thum
# Processing Record 35 of Set 13 | tocopilla
# Processing Record 36 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 13 | turukhansk
# Processing Record 38 of Set 13 | weligama
# Processing Record 39 of Set 13 | beaverlodge
# Processing Record 40 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 13 | hede
# Processing Record 42 of Set 13 | alihe
# Processing Record 43 of Set 13 | vila velha
# Processing Record 44 of Set 13 | sakrand
# Processing Record 45 of Set 13 | amahai
# Processing Record 46 of Set 13 | mandera
# Processing Record 47 of Set 13 | nordstemmen
# Processing Record 48 of Set 13 | mukhanovo
# City not found. Skipping...
# Processing Record 49 of Set 13 | the valley
# Processing Record 50 of Set 13 | gizo
# Processing Record 1 of Set 14 | san juan del sur
# Processing Record 2 of Set 14 | polyarnyy
# Processing Record 3 of Set 14 | bamiantong
# Processing Record 4 of Set 14 | tiruchchendur
# Processing Record 5 of Set 14 | kidal
# Processing Record 6 of Set 14 | sena madureira
# Processing Record 7 of Set 14 | waipawa
# Processing Record 8 of Set 14 | ostrovskoye
# Processing Record 9 of Set 14 | singaparna
# Processing Record 10 of Set 14 | fukue
# Processing Record 11 of Set 14 | lagoa
# Processing Record 12 of Set 14 | geelong
# Processing Record 13 of Set 14 | comarapa
# Processing Record 14 of Set 14 | sao miguel do iguacu
# Processing Record 15 of Set 14 | bad munstereifel
# Processing Record 16 of Set 14 | banepa
# Processing Record 17 of Set 14 | verdalsora
# City not found. Skipping...
# Processing Record 18 of Set 14 | praia da vitoria
# Processing Record 19 of Set 14 | pedro juan caballero
# Processing Record 20 of Set 14 | rancho palos verdes
# Processing Record 21 of Set 14 | toora-khem
# Processing Record 22 of Set 14 | mujiayingzi
# Processing Record 23 of Set 14 | gat
# Processing Record 24 of Set 14 | druzhba
# Processing Record 25 of Set 14 | mecca
# Processing Record 26 of Set 14 | barcelona
# Processing Record 27 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 14 | khanpur
# Processing Record 29 of Set 14 | buer
# Processing Record 30 of Set 14 | noyabrsk
# Processing Record 31 of Set 14 | dordrecht
# Processing Record 32 of Set 14 | bunia
# Processing Record 33 of Set 14 | talcahuano
# Processing Record 34 of Set 14 | las vegas
# Processing Record 35 of Set 14 | songjianghe
# Processing Record 36 of Set 14 | ust-nera
# Processing Record 37 of Set 14 | parainen
# Processing Record 38 of Set 14 | richards bay
# Processing Record 39 of Set 14 | vanavara
# Processing Record 40 of Set 14 | ahuimanu
# Processing Record 41 of Set 14 | alyangula
# Processing Record 42 of Set 14 | tambura
# Processing Record 43 of Set 14 | maniitsoq
# Processing Record 44 of Set 14 | heishan
# Processing Record 45 of Set 14 | roma
# Processing Record 46 of Set 14 | dali
# Processing Record 47 of Set 14 | muros
# Processing Record 48 of Set 14 | churuquita chiquita
# Processing Record 49 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 14 | villa maria
# Processing Record 1 of Set 15 | chaman
# Processing Record 2 of Set 15 | tessalit
# Processing Record 3 of Set 15 | independence
# Processing Record 4 of Set 15 | sao jose da coroa grande
# Processing Record 5 of Set 15 | sanmenxia
# Processing Record 6 of Set 15 | totma
# Processing Record 7 of Set 15 | acarau
# Processing Record 8 of Set 15 | shar
# Processing Record 9 of Set 15 | micheweni
# Processing Record 10 of Set 15 | soroti
# Processing Record 11 of Set 15 | kilindoni
# Processing Record 12 of Set 15 | padang
# Processing Record 13 of Set 15 | litovko
# Processing Record 14 of Set 15 | gandu
# Processing Record 15 of Set 15 | san lawrenz
# Processing Record 16 of Set 15 | okhotsk
# Processing Record 17 of Set 15 | slatina
# Processing Record 18 of Set 15 | saint-louis
# Processing Record 19 of Set 15 | ixtapa
# Processing Record 20 of Set 15 | ye
# City not found. Skipping...
# Processing Record 21 of Set 15 | ranong
# Processing Record 22 of Set 15 | sungairaya
# Processing Record 23 of Set 15 | san juan
# Processing Record 24 of Set 15 | lavrentiya
# Processing Record 25 of Set 15 | charlottesville
# Processing Record 26 of Set 15 | north bend
# Processing Record 27 of Set 15 | shelton
# Processing Record 28 of Set 15 | alice springs
# Processing Record 29 of Set 15 | kloulklubed
# Processing Record 30 of Set 15 | mayo
# Processing Record 31 of Set 15 | grand-santi
# Processing Record 32 of Set 15 | sherghati
# Processing Record 33 of Set 15 | terrace
# Processing Record 34 of Set 15 | stornoway
# Processing Record 35 of Set 15 | mahibadhoo
# Processing Record 36 of Set 15 | qovlar
# Processing Record 37 of Set 15 | gwadar
# Processing Record 38 of Set 15 | aleksandrov gay
# Processing Record 39 of Set 15 | caravelas
# Processing Record 40 of Set 15 | urusha
# Processing Record 41 of Set 15 | trinidad
# Processing Record 42 of Set 15 | abdanan
# Processing Record 43 of Set 15 | kismayo
# Processing Record 44 of Set 15 | soe
# Processing Record 45 of Set 15 | yarada
# Processing Record 46 of Set 15 | charlestown
# Processing Record 47 of Set 15 | lagos
# Processing Record 48 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 15 | saint anthony
# Processing Record 50 of Set 15 | great yarmouth
# Processing Record 1 of Set 16 | talakan
# Processing Record 2 of Set 16 | san luis
# Processing Record 3 of Set 16 | caruray
# Processing Record 4 of Set 16 | stepnyak
# Processing Record 5 of Set 16 | watsa
# Processing Record 6 of Set 16 | mgandu
# Processing Record 7 of Set 16 | husavik
# Processing Record 8 of Set 16 | heinola
# Processing Record 9 of Set 16 | puerto escondido
# Processing Record 10 of Set 16 | bandiagara
# Processing Record 11 of Set 16 | flin flon
# Processing Record 12 of Set 16 | kodinsk
# Processing Record 13 of Set 16 | a
# City not found. Skipping...
# Processing Record 14 of Set 16 | palana
# Processing Record 15 of Set 16 | paysandu
# Processing Record 16 of Set 16 | khandyga
# Processing Record 17 of Set 16 | makokou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Chokurdakh  70.6333  147.9167     37.98        71          16
# 1  Punta Arenas -53.1500  -70.9167     46.42        87           0
# 2        Albany  42.6001  -73.9662     83.14        54          86
# 3   Yellowknife  62.4560 -114.3525     59.52        58          75
# 4       Tautira -17.7333 -149.1500     82.42        79          33
# 5        Hobart -42.8794  147.3294     46.26        71          75
# 6       Mataura -46.1927  168.8643     42.48        98          58
# 7    Bredasdorp -34.5322   20.0403     56.52        77         100
# 8       Kushima  31.4583  131.2333     77.63        96         100
# 9  Longyearbyen  78.2186   15.6401     40.84        81          20
#
#    Wind Speed Country Weather Description
# 0        7.61      RU          few clouds
# 1        5.75      CL           clear sky
# 2        3.62      US     overcast clouds
# 3       18.41      CA       broken clouds
# 4       16.49      PF    scattered clouds
# 5        3.00      AU       broken clouds
# 6        1.90      NZ          light rain
# 7        3.44      ZA     overcast clouds
# 8        4.27      JP       moderate rain
# 9       13.80      SJ          few clouds

# %%
city_data_df.tail(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 698           Husavik  66.0449  -17.3389     52.65        89          72
# 699           Heinola  61.2056   26.0381     60.89        86         100
# 700  Puerto Escondido  15.8500  -97.0667     85.03        70          75
# 701        Bandiagara  14.3501   -3.6104     86.27        52          98
# 702         Flin Flon  54.7682 -101.8650     84.51        30         100
# 703           Kodinsk  58.6881   99.1844     54.05        97          56
# 704            Palana  59.1167  159.9667     50.07        92         100
# 705          Paysandu -32.3214  -58.0756     69.42        60          90
# 706          Khandyga  62.6667  135.6000     60.42        99         100
# 707           Makokou   0.5738   12.8642     70.90        95          99
#
#      Wind Speed Country Weather Description
# 698        2.59      IS       broken clouds
# 699        4.05      FI          light rain
# 700        4.61      MX       broken clouds
# 701       10.09      ML     overcast clouds
# 702       10.36      CA     overcast clouds
# 703        3.56      RU       broken clouds
# 704       23.24      RU          light rain
# 705        6.91      UY     overcast clouds
# 706        3.38      RU       moderate rain
# 707        1.52      GA       moderate rain

# %%
city_data_df.info
# Out:
# <bound method DataFrame.info of              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Chokurdakh  70.6333  147.9167     37.98        71          16
# 1    Punta Arenas -53.1500  -70.9167     46.42        87           0
# 2          Albany  42.6001  -73.9662     83.14        54          86
# 3     Yellowknife  62.4560 -114.3525     59.52        58          75
# 4         Tautira -17.7333 -149.1500     82.42        79          33
# ..            ...      ...       ...       ...       ...         ...
# 703       Kodinsk  58.6881   99.1844     54.05        97          56
# 704        Palana  59.1167  159.9667     50.07        92         100
# 705      Paysandu -32.3214  -58.0756     69.42        60          90
# 706      Khandyga  62.6667  135.6000     60.42        99         100
# 707       Makokou   0.5738   12.8642     70.90        95          99
#
#      Wind Speed Country Weather Description
# 0          7.61      RU          few clouds
# 1          5.75      CL           clear sky
# 2          3.62      US     overcast clouds
# 3         18.41      CA       broken clouds
# 4         16.49      PF    scattered clouds
# ..          ...     ...                 ...
# 703        3.56      RU       broken clouds
# 704       23.24      RU          light rain
# 705        6.91      UY     overcast clouds
# 706        3.38      RU       moderate rain
# 707        1.52      GA       moderate rain
#
# [708 rows x 9 columns]>

# %%
New_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

city_data_df = city_data_df[New_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Chokurdakh      RU  70.6333  147.9167     37.98        71          16
# 1  Punta Arenas      CL -53.1500  -70.9167     46.42        87           0
# 2        Albany      US  42.6001  -73.9662     83.14        54          86
# 3   Yellowknife      CA  62.4560 -114.3525     59.52        58          75
# 4       Tautira      PF -17.7333 -149.1500     82.42        79          33
# 5        Hobart      AU -42.8794  147.3294     46.26        71          75
# 6       Mataura      NZ -46.1927  168.8643     42.48        98          58
# 7    Bredasdorp      ZA -34.5322   20.0403     56.52        77         100
# 8       Kushima      JP  31.4583  131.2333     77.63        96         100
# 9  Longyearbyen      SJ  78.2186   15.6401     40.84        81          20
#
#    Wind Speed Weather Description
# 0        7.61          few clouds
# 1        5.75           clear sky
# 2        3.62     overcast clouds
# 3       18.41       broken clouds
# 4       16.49    scattered clouds
# 5        3.00       broken clouds
# 6        1.90          light rain
# 7        3.44     overcast clouds
# 8        4.27       moderate rain
# 9       13.80          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-85c3a7d8006d> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\.julia\conda\3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\.julia\conda\3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\.julia\conda\3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\.julia\conda\3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
